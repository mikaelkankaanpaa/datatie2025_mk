# %%
import pandas as pd


# Read pedestrian and bicycle traffic data from Tampere open data API

import requests

# Fetch data from API
response = requests.get(url)
data = response.json()

# Save raw response to file for inspection
with open('tampere_traffic_raw.json', 'w') as f:
    f.write(str(data))


df = pd.DataFrame(data['result']['records'])


df

# %%
df = pd.DataFrame(data['result']['records'])

# %%
df
