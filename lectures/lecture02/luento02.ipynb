# %%
from IPython.display import Image
from IPython.core.display import HTML

# %%
import pandas as pd

# %% [markdown]
# # DATATIE Luento 2

# %% [markdown]
# Demo demo

# %%
pd.DataFrame([[1,1]])

# %% [markdown]
# Tämänkin luentomuistion ensimmäisen version toteutti [Arho Suominen](https://www.tuni.fi/fi/ajankohtaista/kun-teknologia-muuttuu-yrityksen-taytyy-loytaa-keinot-sopeutua-muutokseen). Vuonna 2025 DATATIEtä luennoi [Jukka Huhtamäki](https://www.tuni.fi/fi/jukka-huhtamaki).
#
# <hr/>
#
# Kertaus on opintojen äiti ja oppimista tapahtuu koko ajan, joten palataan viime kerran luennolle. Puhuimme siitä, että mikä onkaan datatieteen osaajan profiili. Valitsetko oman osaamisen lokerosi vai onko sinulla vähän kaikkea? Suhteellisen tuore [Harvard Business Review -artikkeli](https://hbr.org/2019/03/why-data-science-teams-need-generalists-not-specialists?utm_campaign=hbr&utm_source=twitter&utm_medium=social) käy läpi ryhmätyön merkitystä datatieteessä.

# %% [markdown]
# <blockquote><p>"There are other downsides to functional specialization. It can lead to loss of accountability and passion from the workers. Smith himself criticizes the division of labor, suggesting that it leads to the dulling of talent—that workers become ignorant and insular as their roles are confined to a few repetitive task. While specialization may provide process efficiencies it is less likely to inspire workers."</p>
#
# <p><footer>--Eric Colson is Chief Algorithms Officer at Stitch Fix. Prior to that he was Vice President of Data Science and Engineering at Netflix.</footer></p>
# </blockquote>

# %% [markdown]
# ## Vinkkejä
#
# - [Oman talouden seuranta: Python & Power BI](https://mkkvkmn.com/oman-talouden-seuranta/#2024-python-power-bi) Mikko Vikman
# - Cursor.AI ja [Vibe coding](https://en.wikipedia.org/wiki/Vibe_coding)

# %% [markdown]
# ## Oppimistavoitteet
#
# Toisen luentoviikon aikana keskitytään datan keräämiseen datatieteen prosessin raaka-aineeksi:
#
# * Minkälaisia datalähteitä on olemassa?
# * Miten dataa kerätään käytännössä?
# * Miten ohjelmointirajapintoja ja ruudunraavintaa hyödynnetään keräämisessä?
# * Mitä seikkoja datan keräämisessä on otettava huomioon?
# * Mitä on laadukas data koneoppimiseen perustuvassa datatieteessä?
#
# Ennen datan keräämiseen sukeltamista tarkastellaan aluksi hetki Hello Jupyter! -tehtävässä kertynyttä aineistoa - siis "raakadataa" [jota ei ole olemassa](https://direct.mit.edu/books/edited-volume/3992/Raw-Data-Is-an-Oxymoron).

# %% [markdown]
# ## Hello Jupyter!
#
# * Plussa-rajapintaa lukeva skripti
# * Samalta käyttäjältä tulleiden palautusten hallinta
# * Muuttujat: merkkijonot vs. kokonaiset tietorakenteet
# * <code>exercises.ipynb</code>
#
#
# Mikä meni pieleen, jos mikään?
#
# Kuinka kerätään laadukasta dataa?
#
# Kumpi onkaan ensin, data vai tietämys?

# %% [markdown]
# # Datatieteen prosessi

# %% [markdown]
# Philip Guo avaa [ACM:n blogissa](https://cacm.acm.org/blogs/blog-cacm/169199-data-science-workflow-overview-and-challenges/fulltext) datatieteen työprosessia.
#
# Kuva esittelee työn neljä päävaihetta: tiedon esikäsittely, vuoropuhelu analyysin ja tulosten reflektion välillä ja lopussa tulosten viestiminen vastaanottajalle soveltuvassa muodossa. Kuvalähde: Kallberg & Ho ([2017](https://www.researchgate.net/publication/319317441_Cyber_Defense_Review_vol22_Summer_2017_CDT_Ho_and_my_book_review_in_the_end)).

# %% [markdown]
# !["Datatieteen työprosessi"](image/guo-data-science-workflow.png)

# %% [markdown]
# Työprosessien tai dataputkien (data pipeline) hallintaan on lukuisia välineitä, muun muassa Papermill ja [Airflow](https://airflow.apache.org/).
#
# Viimeisenä huomiona datatieteen työprosessista on ETL ja DAD. Vincent Granville (2014) kuvasi verkosta sittemmin poistuneessa tekstissään miten ETL (Extract/Load/Transform) on datainsinöörien prosessi ja DAD (Discover/Access/Distill) datatieteen työprosessi.
#
#
# ![etl-vs-dad.png](image/etl-vs-dad.png)
#
# Mikä näissä on erona?
#
# Datainsinöörin keskittyessä ohjelmistotekniikkaan, tietokantasuunnitteluun ja siihen, että data kulkee sujuvasti prosessin lävitse tuottaen keskeiset koosteet tietovirrasta, datatieteilijä keskittyy ymmärtämään datan tuottamaa arvoa. Tämä ei täysin poista prosessiymmärryksen tarvetta, mutta nostaa arvonluonnin datalla keskeisimmäksi elementiksi.

# %% [markdown]
# # Liiketoimintarelevanssi

# %% [markdown]
# ### Miten voidaan perustella data-analytiikan liiketoimintarelevanssi?

# %% [markdown]
# On [osoitettu](https://link.springer.com/article/10.1007/s10796-016-9720-4), että data-analytiikan kyvykkyydet (tunnistaminen, hankkiminen, integraatio, toimittaminen sekä analytiikan työkalut) sekä valmiudet (strategia, johdon tuki, resurssointi) parantavat yrityksen suorituskykyä. Kyse on erityisesti siitä, miten analytiikka voi lisätä ymmärrätystä liiketoimintaprosessista eikä niinkään tavoitteesta korvata ihmistä.

# %% [markdown]
# Tätä ymmärrystä voi auttaa [analytiikan nelikenttä](https://journals.sagepub.com/doi/pdf/10.1177/0256090920130401), joka jaetaan seuraaviin teemoihin
# - Kuvaileva analytiikka
# - Diagnosoiva analytiikka
# - Ennakoiva analytiikka
# - Ohjaava analytiikka

# %% [markdown]
# ![analytiikkatyypit.png](image/analytiikkatyypit.png)

# %% [markdown]
# **Kuvaileva analytiikka** pyrkii selittämään mitä on tapahtunut. Kyse on eri muuttujien tunnistamisesta ja mallintamisesta ajatuksena tuottaa kuvaa siitä mitä prosessissa tapahtuu.
#
# **Diagnosoiva analytiikka** pyrkii selittämään miksi jotain tapahtui. Työ on eksploratiivista nykyisen ja osittain vielä tuntemattoman data kuvailu ja visualisointia, jotta voidaan paremmin ymmärtää miksi jokin tapahtuma on tapahtunut.
#
# **Ennakoiva analytiikka** pyrkii, kuten nimi hyvin toteaa, ennakoivaa tulevaa liiketoimintatilannetta, kuten myyntiä. Kyse on yleisimmin aikasarja-aineiston mallintamisetsa tulevaisuuteen. Hyvä kysymyksen asettelu on, että mitä tulee tapahtumaan?
#
# **Ohjaava analytiikka** pyrkii vastaamaan kysymykseen mitä asialle pitäisi tehdä. Jos taustalla pidetään liiketoiminnan tavoitteet ohjailevalla analytiikalla pyritään tuottamaan ymmärrystä siitä miten nykyistä liiketoiminta prosessia voidaan optiomoida kohti tavoitteita.
#
# **Kartoittava analytiikka** (exploratory) on myös mainitseminen arvoinen osa-alue. Palaamme asiaan visualisoinnin yhteydessä. John Tukey (1980):
#
# <blockquote>Finding the question is often more important than finding the answer. Exploratory data analysis is an attitude, a flexibility, and a reliance on display, NOT a bundle of techniques, and should be so taught. <cite>(<a href="https://www.tandfonline.com/doi/abs/10.1080/00031305.1980.10482706">Tukey, 1980</a>)</cite></blockquote>

# %% [markdown]
# ### Esimerkki ennakoivasta analytiikasta

# %% [markdown]
# Vuoden 2018 AnacondaCon konferenssin yksi mielenkiintoisista esityksistä keskittyi esittelemään, miten rakennetaan laaja ennakoivaan huoltoon keskittyvä järjestelmä toteutetaan. Selkeästi kyseessä on ennakoivan analytiikan muoto, eli se vastaa kysymykseen mitä todennäköisesti tulee tapahtumaan. Esimerkki sisältää myös ohjailevan analytiikan tason, joten on huomattava, että yllä esitetty nelikenttä ei ole "jäykkä" luokittelu vaan ajattelun työväline.

# %%
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/fA0yfemf5n0" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')

# %% [markdown]
# Toinen hyvä esimerkki ennakoivasta analytiikasta löytyy sosiaalisen median datan hyödyntämisestä menekin ennakoimiseen.
#
# [Some-keskustelut ennakoivat menekin kasvua](https://www.kauppalehti.fi/uutiset/some-keskustelut-ennakoivat-menekin-kasvua/bcdf0ca7-6971-48b0-9e03-6d9b46e76006):
#
# <blockquote>"Veganismia koskevien viestimäärien muutokset keskustelufoorumeilla ennakoivat muutoksia kasvismaitotuotteiden myyntivolyymissa kahden viikon viiveellä, ilmenee Helsingin yliopiston Kuluttajatutkimuskeskuksen tutkimuksesta. Neljän tutkijan kirjoittama artikkeli aiheesta on julkaistu tuoreessa Kansantaloudellisessa aikakauskirjassa."</blockquote>

# %% [markdown]
# ### Mikä on analytiikan nykytila yrityksissä

# %% [markdown]
# Vaikka [raportti massadata-analytiikan tilasta](https://www.bain.com/contentassets/5672af3b82f84aa2a80ca732fa8ea06c/bain20_brief_the_value_of_big_data.pdf) on jo auttamatta vanhentunut, antaa se hahmoa yritysten analytiikkakyvystä. Raportin kuva 1 vetää laajan kyselyn tuloksia yhteen seuraavasti:
#
# - Vain 36 % yrityksistä oli erikoistunut data-analytiikkatiimi
# - Vain 19 % yrityksistä oli selkeä ja luotettava dataprosessi
# - Vain 23 % yrityksistä oli selkeä analytiikkastrategia
# - Vain 38 % yrityksistä käytti nykyaikaisia analytiikkatyökaluja
#
# Tiedetään myös, että vuonna 2015 kolmannes suomalaisyrityksistä arvioi massadata-analytiikan vaikuttavan teollisuudenalaansa seuraavan kolmen vuoden aikana ([Giertz, Rickne & Rouvinen, 2015, s. 179](https://www.vinnova.se/contentassets/dac17c64ec524a09b9497f3d9d6b00fa/va_15_06t.pdf)). Analytiikan merkityksestä kertoo sekin, että vuonna 2019 jo [puolet suomalaisyrityksistä jakoi dataa](https://www.etla.fi/ajankohtaista/jo-puolet-suomalaisyrityksista-jakaa-dataa-riskeista-huolimatta-tiedonvaihdosta-on-selvaa-etua-yrityksille/).
# Tuoreen näkemyksen mukaan datan hyödyntäminen edellyttää pehmeän infrastruktuurin kehittämistä teknisen rinnalle ([Peltola, 2023](https://teknologiateollisuus.fi/fi/ajankohtaista/atkn-rajat-tulivat-vastaan-nyt-tarvitaan-pehmeaa-infraa)). Vuonna 2025 keskustelu pyörii luonnollisesti AI-otsikon alla: [The state of AI in early 2024](https://www.mckinsey.com/capabilities/quantumblack/our-insights/the-state-of-ai-2024).

# %% [markdown]
# Mitä tämä tarkoittaa käytännössä?
#
# Auta päivittämään nämä havainnot ja vinkkaa Moodlessa ajantasainen raportti data-analytiikan nykytilasta!

# %% [markdown]
# Hyvän nykytila kuvauksen eri teemoista tarjoaa myös [Sivarajah et al.](https://www.sciencedirect.com/science/article/pii/S014829631630488X#f0005) He eivät käytä samaa nelikenttäjakoa kuin yllä, mutta kuvailevat  erittäin mielenkiintoisella tavalla eri arkkityyppien menetelmiä  ja niiden nykyisiä ja tulevaisuuden mahdollisuuksia. Erittäin suositeltava lukea tai ainakin selailla läpi, kuten myös [X-ketju data-analytiikan nykytilasta](https://twitter.com/jnkka/status/1430228563127644160) tietojohtamisen näkökulmasta.

# %% [markdown]
# # Liiketoimintarelevanssista menetelmiin

# %% [markdown]
# ### Ryömijät ja raapijat (Web crawler & Web scraping)

# %% [markdown]
# Ryömijä (engl. Web crawler, spider, spiderbot tai crawler) on robotti, joka käy systemaattisesti läpi verkko-osoitteita. Tarkoituksena on yleisesti sivujen indeksointi.
#
# Lähtökohtaisesti ryömijä saa käyttäjältä lähtöpisteeksi verkkosivujen osoitteita. Ryömijä käy nämä verkkosivut läpi. Ryömijä kasvattaa omaa hakuavaruuttaan lisäämällä aloituspisteestä löytyvien verkkosivujen sisältämät hyperlinkit omaan hakujonoon, siten kasvattaen omaa hakuavaruuttaan.

# %% [markdown]
# ![Ryömijän työprosessi, lähde Wikipedia](image/crawler-architecture.png)

# %% [markdown]
# Ryömijän toimintaa kontrolloidaan rajoittamalla mitä sivuja ryömijä käsittelee (valinta), milloin sen tulee palata sivuille joissa se on jo käynyt (uudelleenkäynti), miten se estää ylikuormituksen käytävillä sivuilla (kohteliaisuus) ja miten ryömijöiden toimintaa koordinoidaan (rinnakkaistaminen).

# %% [markdown]
# Raapija (engl. Web scraping, web harvesting, tai web data extraction) on työkalu,joka kerää automatisoidusti tieto verkkosivuilta. Käytännön toteutukset ovat yleensä ryömijän ja raapijan yhdistelmiä, joissa ryömijä luo hakuavaruuden lisäämällä hyperlinkkejä hakujonoon ja raapija kerää annettujen parametrien avulla tietoa verkkosivuilta.
#
# Yleisimmin raapija pyrkii tunnistamaan metaelementtejä verkkosivujen rakenteessa ja hyödyntämään näitä käyttäjää kiinnostavan tiedon tallentamiseen. Muina tekniikoina on esimerkiksi semanttiseen rakenteeseen perustuva haku tai sivun ulkoasuun perustuva tunnistaminen.
#
# Tarjolla on [koko joukko raapijoita](https://www.scraperapi.com/blog/the-10-best-web-scraping-tools) yksinkertaisesta [BeautifulSoupista](https://www.crummy.com/software/BeautifulSoup/) kattavaan [Scrapyyn](https://scrapy.org/).

# %% [markdown]
# Tällä opintojaksolla tarkemmassa käsittelyssä on [Scrapy](http://www.scrapy.org). Scrapy on avoimen lähdekoodin ryömijä ja raapija, jolla on kohtuullisen helppo toteuttaa erilaisia datan keruu prosesseja. Nämä voidaan integroida osaksi Python-työprosessia. Alla oleva video on ensimmäinen osa hyvää ohjevideoiden sarjaa Scrapyn käyttämisestä.

# %%
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/ve_0h4Y8nuI" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')

# %% [markdown]
# Kokeillaan tehdä lyhyt esimerkki joka kuvastaa mitä prosessissa saadaan aikaiseksi

# %% [markdown]
# Tehdään esimerkki Shell tilassa
#
#         Scrapy shell
#
# Haetaan verkkosivuna vaikka Verkkokauppa.com puhelinlistauksen ensimmäinen sivu
#
#         fetch('https://www.verkkokauppa.com/fi/catalog/22a/Puhelimet/products?list=1&page=1')
#
# Tämän jälkeen voimme tarkastella mitä saimme noudettua.
#
#         view(response)
#
# Jos haluaisimme ladata kaikki tarjolla olevat puhelimet, niiden nimet sekä tiedot, miten etenisimme? Ainakin olisi saatava selville miten pääsemme käsiksi jokaisen puhelimen tietoihin. Käyttämällä selaimen inspect-toimintoa löysimme metakentän jonka avulla voimme kohdistaa hakumme oikeaan tietoon
#
#         response.xpath("//a[contains(@class, 'thumbnail-link thumbnail-link--grid-full-width')]//@href").extract()
#
# Mitä saimme aikaan?
#
# Katsotaan vielä Finnkinon kotisivua:
#
#         fetch('https://www.finnkino.fi/elokuvat/ohjelmistossa')
#
#         response.xpath("//h2[contains(@class, 'list-item-desc-title no-top-margin no-bottom-margin event-name')]//@href").extract()
#
#
# Näyttääkö erilaiselta? Miksi?

# %%
import requests

# %% [markdown]
# ### Mitä voidaan saada aikaiseksi raapijoita ja ryömijöitä hyödyntämällä?

# %% [markdown]
# Hyrynsalmi ja muut ([2015](https://scielo.conicyt.cl/pdf/jtaer/v10n2/art02.pdf)) keräsivät Google Play -alustalta noin 260 miljoonaa asiakaspalautetta 18 kuukauden ajalta. He osoittivat, että positiiviset palautteet verkkoalustalla korreloivat tilastollisesti merkitsevällä tavalla myynnin kanssa. Arvoiden merkitys näyttää olevan merkitsevämpi kun tarkastelun ajanjakso on pidempi. Arvioilla on myös enemmän merkitystä tilanteessa, jossa tuotteen loppuhinta on suurempi.
#
# Mitä voimme tehdä tällä tiedolla?

# %% [markdown]
# ### Sitten vielä muutama hyvä huomio ryömijöistä ja raapijoista

# %% [markdown]
# Onko raapijoiden ja ryömijöiden käyttö sallittua? Tästä kannattaa lukea ainakin [analyysi raapijoiden ja ryömijöiden laillisuudesta](https://blog.apify.com/is-web-scraping-legal/). Samat kysymykset ovat ajankohtaisia myös [tutkimuksessa](https://rajapinta.co/2018/12/04/kuka-saa-paattaa-mita-dataa-tutkijalla-on-kaytossaan-ei-ainakaan-amerikkalainen-suuryritys/).

# %% [markdown]
# # Datan muodot

# %% [markdown]
# ### Datatyypit

# %% [markdown]
# Datatyypillä tarkoitetaan standardimuotoa jolla ohjelma käsittelee muuttujien sisältämää tietoa. Useimmat järjestelmät tunnistavat ainakin tyypit kokonaisluku, liukuluku ja totuusarvo. Nämä ja muut järjestelmän sallimat datatyypit rajoittavat datalle tehtävissä olevia operaatioita.

# %% [markdown]
# ![Datatyypit Python 3:ssa](https://upload.wikimedia.org/wikipedia/commons/1/10/Python_3._The_standard_type_hierarchy.png)

# %% [markdown]
# Esimerkkinä voisi toimia seuraava todella yksinkertainen kokeilu:

# %%
userInput=input('Anna numero välillä 0-9: ')
try:
    sumValue=1+int(userInput)
    print('Tulos:' + str(sumValue))
    
except ValueError:
    print('Et ilmeisesti antanut numeroa?\n')

# %% [markdown]
# ["If the prompt argument is present, it is written to standard output without a trailing newline. The function then reads a line from input, converts it to a string (stripping a trailing newline), and returns that. When EOF is read, EOFError is raised."](https://docs.python.org/3/library/functions.html#input)

# %%
userInput=input('Anna kokonaisluku välillä 0-9: ')
# userInput=int(userInput)
while userInput.isdigit()==False:
    userInput=input('Ei mennyt ihan nappiin. Anna kokonaisluku välillä 0-9: ')
try:
    sumValue=1+int(userInput)
    print('Lisäsin antamaasi lukuun yhden ja siitä tuli ' + str(sumValue)+".")
except TypeError:
    print('Et ilmeisesti antanut numeroa?')

# %% [markdown]
# ### Datan tallennusmuodot

# %% [markdown]
# Data voidaan käytännössä jakaa kahteen muotoon, tekstimuotoiseen ja binäärimuotoiseen tiedostotyyppiin. Tekstimuotoinen, kuten ASCII, tiedosto on ihmisen luettavissa. Binääritiedosto, kuten JPG-kuva, on vain tietokoneen luettavissa.

# %% [markdown]
# # Datan hallinta

# %% [markdown]
# ### Datan jalostaminen

# %% [markdown]
# Datan jalostaminen (engl. data wrangling tai data munging) on prosessi, jossa tieto muunnetaan ja mallinnetaan, usein "raaka"muodosta (paitsi että [raakadataa ei ole olemassa](https://mitpress.mit.edu/books/raw-data-oxymoron)) muotoon, jossa sitä voidaan hyödyntää analyysissä. Lopputuote riippuu usein käyttötarkoituksesta eli siitä analytiikkaprosessista jonka osa jalostusprosessi on.
#
# Oiva varhainen tietojen jalostaminen keskittynyt projekti oli [Stanford/Berkley Wrangler](http://vis.stanford.edu/wrangler/), jonka lopputuotteeseen voit tutustu alla näkyvästä videosta. Data Wranglerista kehittyi vaiheittain [Trifacta](https://www.trifacta.com/), joka sittemmin siirtyi osaksi [Alteryx-palvelua](https://www.alteryx.com/). Data-analytiikan ekosysteemi kehittyy ja muuttuu jatkuvasti.

# %%
HTML('<iframe src="https://player.vimeo.com/video/19185801" width="640" height="480" frameborder="0" allowfullscreen></iframe>')

# %% [markdown]
# ### Pandas

# %% [markdown]
# DATATIEssä ja datatieteessä laajasti käytössä oleva Pandas on erinomainen väline datan jalostamiseen. Ohessa kokeillaan päästä vauhtiin analysoimalla Kaggle-alustalta löytyvää dataa. Kagglesta löytyy useita eri tunnisteita, joiden avulla voi löytää mielenkiintoista harjoitteludataa eri tarkoituksiin. Esimerkiksi Pandas-kokeilut voi aloittaa [Data Cleaning -osiosta](https://www.kaggle.com/learn/data-cleaning).
#
# Nämä esimerkit käsittelevät [311 Service Request Pitt](https://www.kaggle.com/yoghurtpatil/311-service-requests-pitt) -aineistoa.

# %%
import pandas as pd

# %%
df = pd.read_csv('data/ServreqPitt.csv')
df.tail()

# %%
# Tarkistetaan vaikka aluksi että kaikki ID-arvot ovat yksikäsitteisiä
df['REQUEST_ID'].is_unique

# %%
# Voidaan varmasti olettaa että REQUEST_ID on hyödyllinen ja prosessin kannalta tunnettu indeksi syventyä tietoon.
# Voisimme vaihtaa sen indeksiksi, varsinkin nyt kun tiedämme sen olevan yksikäsitteinen.
df.set_index('REQUEST_ID', inplace=True)
df.head()

# %%
# Mitkä datatyypit vaikuttavat virheellisiltä?
df.dtypes

# %% [markdown]
# ![Pandan datatyypit](https://pbpython.com/images/pandas_dtypes.png)

# %%
# Katsotaan tarkemmin kahta saraketta
df[['FIRE_ZONE', 'POLICE_ZONE']].head()

# %%
# Mitä huomattiin edellisestä?
df['FIRE_ZONE'] = df['FIRE_ZONE'].astype('category')
df['POLICE_ZONE'] = df['POLICE_ZONE'].astype('category')
# Päivitysten myötä rikkoontunut versio koodista
# df[['FIRE_ZONE', 'POLICE_ZONE']]=df[['FIRE_ZONE', 'POLICE_ZONE']].astype('category')

# %%
# Mitä saatin aikaan?
df.dtypes

# %%
# Olisiko voinut tehdä siistimmin?
dfZone=df[['FIRE_ZONE', 'POLICE_ZONE']]
dfZone.head()

# %%
# Ovatko alueet poliiseilla ja palokunnalla samanlaisia?
dfZone.groupby(['FIRE_ZONE', 'POLICE_ZONE']).size()

# %%
pd.set_option('display.max_rows', None)
dfZone.groupby(['POLICE_ZONE', 'FIRE_ZONE']).agg('size')

# %%
dfZone.groupby(['FIRE_ZONE', 'POLICE_ZONE']).size()

# %%
# Muutetaan aikatieto oikean muotoon
df['TimeStamp'] =  pd.to_datetime(df['CREATED_ON'], format='%Y%m%dT%H:%M:%S',  errors='raise')

# %%
df['TimeStamp'].head()

# %%
# Tarkistetaan tietorakenteen koko
df.shape

# %%
# Poistetaan rivit joissa on tyhjiä arvoja - onko hyvä ajatus?
df = df.dropna(axis=0)

# %%
# Mitä on käynyt tietorakenteelle?
df.shape

# %%
df.groupby('REQUEST_ORIGIN').count()

# %% [markdown]
# Lopuksi, kunnollinen [toimintokooste](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Pandas_Cheat_Sheet_2.pdf) eli "cheat sheet" on aina hyödyllinen.
#
#
# # Lopuksi
#
# 1. Tekoälyllä (GenAI, kielimalli) voi automatisoida tai augmentoida datan käsittelyprosesseja, mutta se ei voi toimia datan lähteenä
# 1. Dataa on käytännössä aina jalostettava ja yleensä merkittävästikin - raakadataa ei ole olemassa
# 1. Ohjelmointi mahdollistaa uusia keinoja datan keräämiseen, mutta niiden soveltamisessa on huomioitava etiikka ja lainsäädäntö

# %% [markdown]
# <!--
# * Raapijat ja ryömijät hyödyllisiä - eettiset ja lailliset kysymykset
# * Big data vs. smart data - määrä ei aina korvaa laatua
# * Kannattaako datatieteilijän erikoistua vai kehittää laajaa osaamista (ehkä jälkimmäinen)
# * Datan jalostaminen vaatii resursseja - 80/20-sääntö
# -->

# %% [markdown]
# <!--
# * Raapijat ja ryömijät hyödyllisiä - eettiset ja lailliset kysymykset
# * Big data vs. smart data - määrä ei aina korvaa laatua
# * Kannattaako datatieteilijän erikoistua vai kehittää laajaa osaamista (ehkä jälkimmäinen)
# * Datan jalostaminen vaatii resursseja - 80/20-sääntö
# -->

# %% [markdown]
# Edelliset vuodet
# <!--
#
#
# **2024**
#
# 1. Datan laatu vaihtelee, koodaamalla voimme jalostaa sitä - tähän on syytä varata aikaa
# 1. Ammattimaisen datatiedeprosessin pystyttäminen on työlästä, mutta liikkeelle pääsee kevyesti
# 1. Datatiedeprojeitessa on syytä huomioida lainsäädäntö ja etiikka
#
# **2022**
#
# 1. Kysymyksestä lähdetään liikkeelle, josta siirrytään datalähteen valintaan ja datan jalostamiseen - edetään iteratiivisesti
# 2. Jos ohjelmointirajapintaa ei ole tarjolla, voidaan hyödyntää ruudunraavintaa
# 3. Pickle on Pythonin tapa tallentaa tietorakenteita sellaisenaan tiedostoon - aina on uutta opittavaa
# -->
